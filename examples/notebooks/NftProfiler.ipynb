# %%
from messari.nfts import (
    NFTPriceFloor,
    NonFungible,
    OpenSea,
)

import requests
from string import Template
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Testing OpenSea API 
HEADERS = {'Accept': 'application/json'}
ASSET_URL = Template('https://api.opensea.io/api/v1/asset/$contract/$id/')
CONTRACT_URL = Template('https://api.opensea.io/api/v1/asset_contract/$contract')
COLLECTION_URL = Template('https://api.opensea.io/api/v1/collection/$collection')
STATS_URL = Template('https://api.opensea.io/api/v1/collection/$collection/stats')
EVENTS_URL = 'https://api.opensea.io/api/v1/events'

# %%
url = CONTRACT_URL.substitute(contract="0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb")
response = requests.get(
    url,
    headers=HEADERS,
)

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en-US">\n   <head>\n      <title>Access denied</title>\n      <meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n      <meta name="robots" content="noindex, nofollow" />\n      <meta name="viewport" content="width=device-width,initial-scale=1" />\n      <link rel="stylesheet" href="/cdn-cgi/styles/errors.new.min.css" media="screen" />\n      <script>\n(function(){if(document.addEventListener&&window.XMLHttpRequest&&JSON&&JSON.stringify){var e=function(a){var c=document.getElementById("error-feedback-survey"),d=document.getElementById("error-feedback-success"),b=new XMLHttpRequest;a={event:"feedback clicked",properties:{errorCode:1020,helpful:a,version:3}};b.open("POST","https://sparrow.cloudflare.com/api/v1/event");b.setRequestHeader("Content-Type","application/json");b.setRequestHeader("Sparrow-Source-Key","c771f0e4b54944bebf4261d44bd79a1e");\nb.send(JSON.stringify(a));c.classList.add("feedback-hidden");d.classList.remove("feedback-hidden")};docum
# ...

# %%
# Instantiate API connections 
nft_price_floor = NFTPriceFloor()
non_fungible = NonFungible()
opensea = OpenSea()

# %%
# Collections of interest to profile 
# Names are slightly different for each source 

nft_price_floor_collections = [
    'boredApesYC',
    'coolCats',
    'cryptoPunks',
]

non_fungible_collections = [
    'cryptopunks',
    'doodles',
]

opensea_collections = [
    'doodles-official',
]

opensea_contract_addresses = [
    '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb', # punks
    '0xBC4CA0EdA7647A8aB7C2061c2E118A18a936f13D', # BAYC
]

# %%
# # Getting NFT Price Floor data 

nfts = nft_price_floor.get_nfts()
# nfts.head()
# df_floors = nft_price_floor.get_floor(nft_price_floor_collections)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/opt/anaconda3/envs/env/lib/python3.9/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     <a href='file:///Users/alexkan/opt/anaconda3/envs/env/lib/python3.9/site-packages/urllib3/connection.py?line=172'>173</a> try:
# --> <a href='file:///Users/alexkan/opt/anaconda3/envs/env/lib/python3.9/site-packages/urllib3/connection.py?line=173'>174</a>     conn = connection.create_connection(
#     <a href='file:///Users/alexkan/opt/anaconda3/envs/env/lib/python3.9/site-packages/urllib3/connection.py?line=174'>175</a>         (self._dns_host, self.port), self.timeout, **extra_kw
#     <a href='file:///Users/alexkan/opt/anaconda3/envs/env/lib/python3.9/site-packages/urllib3/connection.py?line=175'>176</a>     )
# ...

# %%
df_collection_history = non_fungible.get_collection_history(collections_in=non_fungible_collections, length=5)
df_collection_stats = non_fungible.get_collection_stats(collections_in=non_fungible_collections)
df_collection_summary = non_fungible.get_collection_summary(collections_in=non_fungible_collections)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /Users/alexkan/work/api/messari-python-api-private/examples/notebooks/NftProfiler.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/alexkan/work/api/messari-python-api-private/examples/notebooks/NftProfiler.ipynb#ch0000006?line=0'>1</a> df_collection_history = non_fungible.get_collection_history(collections_in=non_fungible_collections, length=5)
#       <a href='vscode-notebook-cell:/Users/alexkan/work/api/messari-python-api-private/examples/notebooks/NftProfiler.ipynb#ch0000006?line=1'>2</a> df_collection_stats = non_fungible.get_collection_stats(collections_in=non_fungible_collections)
# ...

# %%
df_contracts = opensea.get_contract(contracts_in=opensea_contract_addresses)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /Users/alexkan/work/api/messari-python-api-private/examples/notebooks/NftProfiler.ipynb Cell 6' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/alexkan/work/api/messari-python-api-private/examples/notebooks/NftProfiler.ipynb#ch0000007?line=0'>1</a> df_contracts = opensea.get_contract(contracts_in=opensea_contract_addresses)
#
# File ~/opt/anaconda3/envs/env/lib/python3.9/site-packages/messari/nfts/opensea/opensea.py:95, in OpenSea.get_contract(self, contracts_in)
#      <a href='file:///Users/alexkan/opt/anaconda3/envs/env/lib/python3.9/site-packages/messari/nfts/opensea/opensea.py?line=92'>93</a> for contract in contracts:
# ...
