# %%
from messari.coinglass import coinglass
cg = coinglass()

# %%
print(cg.get_symbols())
# Out:
# ['BTC', 'ETH', 'SOL', 'XRP', 'USDT', 'ETC', 'MATIC', 'ADA', 'BNB', 'DOT', 'GMT', 'LTC', 'TRX', 'AVAX', 'BCH', 'SAND', 'EOS', 'LINK', 'DOGE', 'APE', 'AXS', 'FTT', 'NEAR', 'AAVE', 'FIL', 'ATOM', 'CRV', 'WAVES', 'FTM', 'UNI', 'MANA', 'OP', 'RUNE', 'DYDX', 'GALA', 'SUSHI', 'ZIL', 'ALGO', '1000SHIB', 'XMR', 'XTZ', 'XLM', 'BSV', 'SNX', 'SRM', 'PEOPLE', 'FLM', 'RSR', 'THETA', 'COMP', 'EGLD', 'GRT', 'SHIB', 'ICP', 'AR', 'STORJ', '1INCH', 'ENS', 'ZEC', 'KNC', 'YFI', 'BIT', 'YFII', 'CHZ', 'MKR', 'UNFI', 'BNX', 'CEL', 'LOOKS', 'LRC', 'ENJ', 'ONE', 'VET', 'KSM', 'NEO', 'GAL', 'CRO', 'TRB', 'OGN', 'DASH', 'BAT', 'MTL', 'LUNA2', 'OMG', 'QTUM', 'KAVA', 'ZRX', 'JASMY', 'XEM', 'IMX', 'REN', 'RAY', '1000LUNC', 'ALT', 'IOTA', 'ALICE', 'IOST', 'SXP', 'FLOW', 'CELO', 'SHIT', 'HNT', 'BTCDOM', 'ROSE', 'AUDIO', 'NKN', 'LUNA', 'C98', 'ONT', 'CVX', 'HBAR', 'ZEN', 'LIT', 'SKL', 'RVN', 'BAL', 'MASK', 'ALPHA', 'GST', 'DEFI', 'CHR', 'YGG', 'DENT', 'IOTX', 'SHIB1000', 'LPT', 'API3', 'ANKR', 'SLP', 'BEL', 'BAKE', '
# ...

# %%
cg.get_funding_rate('BTC').tail()
# Out:
#                          Bitmex   Binance  Bybit      Okex     Huobi    Gate  \
# 2022-07-17 16:00:00.000    0.01  0.008805   0.01  0.013615  0.010000  0.0100
# 2022-07-18 00:00:00.000    0.01  0.010000   0.01  0.006452  0.004958  0.0092
# 2022-07-18 08:00:00.000    0.01  0.010000   0.01  0.010603  0.000875  0.0096
# 2022-07-18 16:00:00.000    0.01  0.010000   0.01  0.009466  0.010000  0.0074
# 2022-07-18 21:17:14.502    0.01  0.010000   0.01  0.012438  0.010000  0.0100
#
#                             FTX  Bitget      dYdX    CoinEx    price
# 2022-07-17 16:00:00.000  0.0000 -0.0094  0.015697  0.013719  21158.5
# 2022-07-18 00:00:00.000  0.0024  0.0045  0.015549 -0.054418  20780.1
# 2022-07-18 08:00:00.000  0.0120 -0.0100  0.024651 -0.055513  22251.7
# 2022-07-18 16:00:00.000  0.0016 -0.0100  0.027242 -0.023426  22682.4
# 2022-07-18 21:17:14.502  0.0000 -0.0100  0.023914 -0.139892  21581.8

# %%
cg.get_liquidations('BTC').tail()
# Out:
#         Binance                                                               \
#    exchangeName     buyVolUsd    sellVolUsd turnoverNumber buyTurnoverNumber
# 85      Binance  9.062034e+06  4.817966e+06           2395              1394
# 86      Binance  5.940213e+06  3.834248e+06           2139              1195
# 87      Binance  4.657464e+06  5.291761e+06           1920              1112
# 88      Binance  3.384439e+06  4.019904e+06           1746               816
# 89      Binance  1.321888e+07  9.709615e+06           3966              2463
#
#                                               FTX                ... Bitfinex  \
#    sellTurnoverNumber sellQty buyQty exchangeName     buyVolUsd  ...   buyQty
# 85               1001       0      0          FTX  4.131245e+06  ...        0
# 86                944       0      0          FTX  8.618914e+05  ...        0
# 87                808       0      0          FTX  1.833055e+06  ...        0
# ...

# %%
cg.get_open_interest('BTC').tail()
# Out:
#                               Binance        Bitmex         Bybit  \
# 2022-07-15 00:00:00.000  3.061137e+09  3.151223e+08  1.399086e+09
# 2022-07-16 00:00:00.000  3.141495e+09  3.175361e+08  1.458969e+09
# 2022-07-17 00:00:00.000  3.205558e+09  3.128291e+08  1.415769e+09
# 2022-07-18 00:00:00.000  3.178419e+09  3.050814e+08  1.406447e+09
# 2022-07-18 21:17:29.125  3.288488e+09  3.039183e+08  1.419185e+09
#
#                                   CME          Okex           FTX  \
# 2022-07-15 00:00:00.000  1.392145e+09  2.066779e+09  1.640470e+09
# 2022-07-16 00:00:00.000  1.427948e+09  1.985583e+09  1.665316e+09
# 2022-07-17 00:00:00.000  1.457869e+09  2.053331e+09  1.669196e+09
# 2022-07-18 00:00:00.000  1.429732e+09  2.094861e+09  1.648739e+09
# 2022-07-18 21:17:29.125  1.484768e+09  2.146653e+09  1.663301e+09
#
#                              Deribit        Kraken      Bitfinex  \
# 2022-07-15 00:00:00.000  748545630.0  4.120984e+07  1.075038e+08
# ...
